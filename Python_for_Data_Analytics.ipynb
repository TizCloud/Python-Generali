# %% [markdown]
# ##Python Programming

# %%
print ('Welcome to Python Programming')
print ("Basic Python Programming")

print ("My name's Tissana")

print (100)
print (375.5)

print()

print ("100")

print (100 + 200)
print ("100"+"200")

# print (100 + "200")

# %%
mydata = 30
print(f'Date : {mydata}')

language = 'Python'
title = f'This is {language} Programming'
print(title)

print(f"{language} for Data Analytics")

home = 0
away = 6
result = F"ManU {home} - {away} Liverpool"
print(result)

# %% [markdown]
# ## String

# %%
mystring = "Python Programming"

print("mystring[7] :" , mystring[7])
print("mystring[1:5] :" , mystring[1:5])

# %%
mystring = 'Python'

print("mystring[-1]: ", mystring[-1])
print("mystring[-2]: ", mystring[-2])
print("mystring[-6]: ", mystring[-6])

# %%
mystring = "Welcome to Python Programming"

print('mystring[5] : ', mystring[5])
print('mystring[2:10] : ', mystring[2:10])
print('mystring[2:18:2] : ', mystring[2:18:2])
print('mystring[:8] : ', mystring[:8])
print('mystring[8:] : ', mystring[8:])
print('mystring[::3] : ', mystring[::3])
print('mystring[::-2] : ', mystring[::-2])

# %% [markdown]
# #List

# %%
mylst = [10, 20, 30, 40, 'Python', 50, 'Java']
print(mylst)
print(type(mylst))

print('------------------------------')

mylist1 = [] # Empty List
mylist2 = [10, 20, 30, 40, 50]
mylist3 = ["Thailand", "Singapore", "Malaysia", "Vietnam"]
mylist4 = ['Python', 'Java', 1994, 1996]
mylist5 = ["Name", "Surname", 300, 0.5, mylist2]

print(mylist1)
print(mylist2)
print(mylist3)
print(mylist4)
print(mylist5)

# %%
mylist1 = ['Thailand', 'Vietnam', 2017, 2021]
mylist2 = [100, 200, 300, 400, 500, 600, 700, 800]

print("mylist1[0]: ", mylist1[0])
print("mylist1[-1]: ", mylist1[-1])
print("mylist2[3]: ", mylist2[3])
print("mylist2[-5]: ", mylist2[-5])
print("mylist2[1:5]: ", mylist2[1:5])
print("mylist2[::2]: ", mylist2[::2])
print("mylist2[2::2]: ", mylist2[2::2])
print("mylist2[2:8:2]: ", mylist2[2:8:2])
print("mylist2[:8]: ", mylist2[:8])
print("mylist2[5:]: ", mylist2[5:])

# %%
mylist1 = ['Thailand', 'Vietnam', 2017, 2021]
print("Old Value : ", mylist1[2])

mylist1[2] = 2023
print("New Value : ", mylist1[2])

print('-------------------------')


mylist2 = ['Python', 'c#', 1994, 2000]
print("Before deleting : ", mylist2)

del mylist2[2]
print("After deleting : ", mylist2)

# %%
mylst = [i*1 for i in range(10)]

print("List Member: ", mylst)
print('-------------------------')

del mylst[0], mylst[2], mylst[4]
print("List After Remove Member: ", mylst)
print('-------------------------')

#del mylst
#print("List After Remove Member: ", mylst)

# %% [markdown]
# #Tuple

# %%
mytup1 = (100, 50.75)
mytup2 = ('Python', 'Java')
mytup3 = (30, 15.5, "Thailand", "Malaysia")
mytup4 = (mytup1, mytup2, mytup3)
mytup5 = mytup1 + mytup2
mytup6 = ()

print(mytup1)
print(mytup2)
print(mytup3)
print(mytup4)
print(mytup5)
print(mytup6)

print(type(mytup1))

# %%
mytup1 = (("Name", "Sunisa"), ("Age", "38"),("Gender", "Female"))

print(mytup1[0])
print(mytup1[1])
print(mytup1[2])

mytup2 = (100, 35.75)
mytup2[0] = 155
mytup2[1] = 75.55
print(mytup2)

# %%
mytup = ('Arsenal', 'Manchester City', 2002, 2022)
print(mytup)
print(mytup[0])
print(mytup[1])
print(mytup[2])
print(mytup[3])

#del mytup[2]
#print("After mytup[2] Deleted : ", mytup)

#del mytup
#print(mytup)

# %% [markdown]
# ##Dictionary

# %%
mydict1 = {}
mydict2 = {'Arsenal' : '75', 'Liverpool' : '78' , 'Newcastle' : '80'}
mydict3 = {'Aston Villa' : 56}
mydict4 = {'Man U' : 47 , 2023 : 20}

print(mydict1)
print(mydict2)
print(mydict3)
print(mydict4)

print(type(mydict1))

# %%
mydict = {'Name' : 'Sunisa' , 'Age' : 30 , 'Class' : 'First'}

print("mydict['Name']: " , mydict['Name'])
print("mydict['Age']: " , mydict['Age'])
print("mydict['Class']: " , mydict['Class'])

# %%
mydict1 = {}
print("Original Dictionary : ", mydict1)

mydict1['Key1'] = 150
print("Update data1 to dictionary : ", mydict1)

mydict1['Key2'] = 450
print("Update data2 to dictionary : ", mydict1)

# %%
mydict = {'Name' : 'Sunisa' , 'Age' : 30 , 'Class' : 'First'}
print("Original Dictionary : ", mydict)

del mydict['Class']
print ("After removed :", mydict)

mydict.clear()
print ("After clear :", mydict)

del mydict
print ("After deleted :", mydict)

# %%
mydic1 = {1:"Python", 2:"Java", 3:"SQL", 4:"R"}
for i in mydic1:
  print(mydic1[i])

mydic2 = {"Lage":"Python", 2:(100, 200), 3:[30, 40, 50], 4:{'Name' : 'Sunisa'}}
for i in mydic2:
  print(mydic2[i])

# %% [markdown]
# ##if statements

# %%
myname = input ("Enter name :")
price = float(input("Enter price of %s :" %myname))

if price >= 1000:
  temp = price * 0.05
  price = price - temp

vat = price * 0.07
price = price + vat

print("The price of %s (inc VAT 7%%) is %.2f %s and VAT %.2f %s" %(myname, price, "Baht.", vat , "Baht." ))

# %%
mynum = int(input ("Enter Integer Number :"))

if mynum % 2 == 0:
  print("%d is Even Number" %mynum)
else:
  print("%d is Odd Number" %mynum)

# %%
myscore = float(input("Enter your score : "))
mymsg = "Your grade is "

if myscore >= 80:
  print(mymsg + "A")
elif myscore >= 70:
  print(mymsg + "B")
elif myscore >= 60:
  print(mymsg + "C")
elif myscore >= 50:
  print(mymsg + "D")
else
  print(mymsg + "F")

# %%
myvar = 200

if myvar < 200:
  print("Expression value is less than 200")
elif myvar < 500:
  print("Expression value is less than 500")
  if myvar == 400:
    print("Which is 400")
  elif myvar == 300:
    print("Which is 300")
  elif myvar == 200:
    print("Which is 200")
else:
  print("False Expression")

# %% [markdown]
# ##While Loop

# %%
count = 0

while (count < 10):
  print ('This count is: ', count)
  count = count + 1

print('The End')

# %%
count = 0

while count < 9 :
  print (count, "is less than 9.")
  count = count + 1
else:
  print (count, "is not less than 9.")

# %%
count = 1
sum = 0.0

print ("Exit this program, please type 0 or 0.0 :")

mynum = float(input("Enter a number : "))

while mynum != 0 or mynum != 0.0:
  sum += mynum  # Sum = sum + mynum
  avg = sum / count
  count += 1    # count = count + 1
  print("Average of number is : ", avg)
  mynum = float(input("Enter a number : "))

# %%
for chr in 'Python':
  if chr == 'h':
    break
  print('Current Character :', chr)

print ("--------------------------------")

myvar = 10
while myvar > 0 :
  print ('Current variable value :', myvar)
  myvar = myvar - 1
  if myvar == 5:
    break

# %%
for chr in 'Python':
  if chr == 'h':
    continue
  print('Current Character :', chr)

print ("--------------------------------")

myvar = 10
while myvar > 0 :
  myvar = myvar - 1
  if myvar == 5:
    continue
  print ('Current variable value :', myvar)

# %%
for chr in 'Python':
  if chr == 'h':
    pass
    print('This is pass block')
  print('Current Character :', chr)

# %%
mynum = int(input("Enter integer number (odd) : "))
flag = False
num = 1

for i in range(3, mynum+2 , 2):  # i = 3
  if flag == False:
    num = num - (1 / i)         # num = 0
    flag = True
  else:
    num = num + (1 / i)
    flag = False
print("result of PI/4 = %.4f" %num)

# %% [markdown]
# #Python for Data Analytics

# %% [markdown]
# Series คือโครงสร้างข้อมูลแบบ 1 มิติ ทำหน้าที่เก็บข้อมูลเรียงกันเป็นแถวหรือคอลัมน์เดียว คล้ายกับคอลัมน์ใน Excel หรือ List
#
# Series จะมี Value กับ Index

# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
obj = pd.Series([4, 7, -5, 3])
obj

# %%
obj.values

# %%
obj.index

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['a', 'b', 'c', 'd'])
obj2

# %%
obj2.index

# %%
obj2['d'] = 6
obj2[['d', 'c', 'a']]

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
obj3

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)
obj4

# %%
pd.isnull(obj4)

# %%
pd.notnull(obj4)

# %%
obj4.isnull()

# %%
obj4.name = 'population'
obj4.index.name = 'state'
obj4

# %% [markdown]
# ### DataFrame

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)
frame

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
                      index=['one', 'two', 'three', 'four', 'five', 'six'])
frame2

# %%
frame2['state']

# %%
frame2.year

# %%
frame2

# %%
frame2.loc['three']

# %%
frame2

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=['two', 'four', 'five'])
frame2['debt'] = val
frame2

# %%
frame2['eastern'] = frame2.state == 'Ohio'
frame2

# %%
pop = {'Nevada': {2001: 2.4, 2002: 2.9}, 'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}

frame3 = pd.DataFrame(pop)
frame3

# %%
frame3.T

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])

uniques = obj.unique()
uniques

# %% [markdown]
# ## Reading and Writing Data in Text Format

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/drive/MyDrive/data/ex1.csv')
df

# %%
pd.read_table('/content/drive/MyDrive/data/ex1.csv', sep=',')

# %%
pd.read_csv('/content/drive/MyDrive/data/ex2.csv', header=None)

# %%
pd.read_csv('/content/drive/MyDrive/data/ex2.csv',
            names=['a', 'b', 'c', 'd', 'message'])

# %%
names = ['a', 'b', 'c', 'd', 'message']

pd.read_csv('/content/drive/MyDrive/data/ex2.csv',
            names=names, index_col='message')

# %%
parsed = pd.read_csv('/content/drive/MyDrive/data/csv_mindex.csv',
                     index_col=['key1', 'key2'])
parsed

# %%
pd.read_csv('/content/drive/MyDrive/data/ex4.csv', skiprows=[0, 2, 3])

# %%
result = pd.read_csv('/content/drive/MyDrive/data/ex5.csv')
result

# %%
pd.isnull(result)

# %%
result = pd.read_csv('/content/drive/MyDrive/data/ex5.csv',
                     na_values=['NULL'])
result

# %%
pd.read_csv('/content/drive/MyDrive/data/ex5.csv')

# %%
sentinels = {'message': ['foo', 'NA'], 'something': ['two']}
pd.read_csv('/content/drive/MyDrive/data/ex5.csv', na_values=sentinels)

# %%
result = pd.read_csv('/content/drive/MyDrive/data/ex6.csv')
result

# %%
pd.read_csv('/content/drive/MyDrive/data/ex6.csv', nrows=5)

# %% [markdown]
# ### Writing Data to Text Format

# %%
data = pd.read_csv('/content/drive/MyDrive/data/ex5.csv')
data

# %%
data.to_csv('/content/drive/MyDrive/data/out.csv')

# %%
import csv

f = open('/content/drive/MyDrive/data/ex7.csv')

reader = csv.reader(f)

for line in reader:
    print(line)

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38, "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
import json

result = json.loads(obj)
result

# %%
asjson = json.dumps(result)

siblings = pd.DataFrame(result['siblings'], columns=['name', 'age', 'pets'])
siblings

# %%
data = pd.read_json('/content/drive/MyDrive/data/example.json')
data

# %%
tables = pd.read_html('/content/drive/MyDrive/data/fdic_failed_bank_list.html')
len(tables)
failures = tables[0]
failures.head()

# %%
from lxml import objectify

path = '/content/drive/MyDrive/data/Performance_MNR.xml'
parsed = objectify.parse(open(path))
root = parsed.getroot()

data = []

skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ', 'DESIRED_CHANGE', 'DECIMAL_PLACES']

for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

perf = pd.DataFrame(data)
perf.head()

# %%
xlsx = pd.ExcelFile('/content/drive/MyDrive/data/ex1.xlsx')

frame = pd.read_excel(xlsx, 'Sheet1')
frame

# %%
import pandas as pd

with pd.ExcelWriter('/content/drive/MyDrive/data/output4.xlsx', engine='openpyxl') as writer:
    df.to_excel(writer, sheet_name='Sheet1')

# %% [markdown]
# **Data Cleaning and Preparation**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Handling Missing Data

# %%
string_data = pd.Series(['aardvark', 'artichoke', np.nan, 'avocado'])
string_data

# %%
string_data.isnull()

# %%
string_data[0] = None
string_data.isnull()

# %%
from numpy import nan as NA

data = pd.Series([1, NA, 3.5, NA, 7])
data

# %%
data.dropna()

# %%
data[data.notnull()]

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., NA, NA], [NA, NA, NA], [NA, 6.5, 3.]])
data

# %%
cleaned = data.dropna()
cleaned

# %%
data

# %%
data.dropna(how='all')

# %%
data[4] = NA
data

# %%
data.dropna(axis=1, how='all')

# %%
df = pd.DataFrame(np.random.randn(6, 3))
df.iloc[2:, 1] = NA
df.iloc[4:, 2] = NA
df

# %%
df.fillna(method='ffill')

# %%
data = pd.Series([1., NA, 3.5, NA, 7])
data.fillna(data.mean())

# %% [markdown]
# ### Removing Duplicates

# %%
data = pd.DataFrame({'k1': ['one', 'two'] * 3 + ['two'],
                     'k2': [1, 1, 2, 3, 3, 4, 4]})
data

# %%
data.duplicated()

# %%
data.drop_duplicates()

# %%
data['v1'] = range(7)
data

# %%
data.drop_duplicates(['k1'])

# %%
data

# %%
data.drop_duplicates(['k1', 'k2'], keep='last')

# %% [markdown]
# ### Replacing Values

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data

# %%
data.replace(-999, np.nan)

# %%
data

# %%
data.replace([-999, -1000], np.nan)

# %%
data.replace([-999, -1000], [np.nan, 0])

# %%
data.replace({-999: np.nan, -1000: 0})

# %% [markdown]
# ### Data and Time

# %%
from datetime import datetime
from datetime import date
from datetime import time

# %%
now = datetime.now()
today = date.today()
curtime = datetime.now().time()

display(now, today, curtime)

# %%
dt = datetime(2020, 7, 23, 12, 22, 32)
print(dt)

dt2 = dt.replace(year=2022, month=2, day=14)
print(dt2)

# %%
dt = datetime(2020, 7, 23, 12, 22, 32)
print(dt.day)
print(dt.month)

d = datetime(2020, 7, 23)
print(d.year)
print(d.weekday())

t = datetime.now().time()
print(t.hour)

# %%
from datetime import date

wd = ['อาทิตย์', 'จันทร์', 'อังคาร', 'พุธ', 'พฤหัสบดี', 'ศุกร์' 'เสาร์']
d = date(2020, 7, 23)
w = d.weekday()
if w == 6:
    w = 0
else:
    w += 1

print('weekday => ', wd[w])

# %%
from datetime import date

months = ['มกราคม', 'กุมภาพันธ์', 'มีนาคม', 'เมษายน', 'พฤษภาคม', 'มิถุนายน',
          'กรกฎาคม', 'สิงหาคม', 'กันยายน', 'ตุลาคม', 'พฤศจิกายน', 'ธันวาคม']

d = date(2020, 12, 23)
month_name = months[d.month - 1]  #ต้องลบด้วย 1 เพราะลำดับของลิสต์อยู่ระหว่าง 0 - 11

month_name

# %%
from datetime import date
from datetime import timedelta

d1 = date(2020, 8, 12)
d2 = date(2020, 12, 5)
delta = d2 - d1
print(delta)

days = delta.days
num_months = days // 30
num_days = days % 30
print(f'วันที่ 5 ธันวาคม และ 12 สิงหาคม ห่างกัน {num_months} เดือน {num_days} วัน')

birthday = date(2002, 3, 31)
today = date.today()
delta = today - birthday
days = delta.days
age = days // 365
print(age)

# %% [markdown]
# ## matplotlib

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [5, 15, 15, 20, 10]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

y = [5, 20, 10, 15, 10]
x = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-darkgrid')

y = (15, 12, 19, 13, 16, 17, 12)
x = ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']

plt.title('Sales by Week', fontname='sans-serif', color='blue', alpha=0.8)

plt.ylabel('Sale', color='m', fontname='sans-serif', fontsize=14)
plt.xlabel('Day', color='g', fontname='sans-serif', fontsize=14)

plt.yticks(color='r')
plt.xticks(rotation='vertical', color='r', fontname='sans-serif', fontsize=13)

plt.plot(x, y)
plt.show()

# %%
print(plt.style.available)

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-darkgrid')

y = [6, 8, 5, 7]
x = [1, 2, 3, 4]

plt.plot(x, y, '--ro')
plt.grid(color='g', alpha=0.1, lw=2, linestyle='--')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-whitegrid')

y = [10, 15, 15, 20, 10]
x = [1, 2, 3, 4, 5]
plt.plot(x, y, ls='-', c='r', label='Item #1')

y = [15, 25, 10, 15, 20]
plt.plot(x, y, ls='--', c='g', label='Item #2')

y = [10, 20, 15, 10, 15]
plt.plot(x, y, ls=':', c='b', label='Item #3')

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.size'] = 14
plt.legend(loc='best')

plt.show()

# %%
import matplotlib.pyplot as plt


y = [50, 70, 35, 90, 40]
x = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']

plt.bar(x, y, color='g', alpha=1.0)
plt.xticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use("ggplot")

y = [2, 4, 1, 2, 3, 2, 1, 2, 3, 2]
x = np.arange(1, 11)

plt.bar(x, y, color='m')
plt.title('Bar Plot')
plt.xlabel('Play')
plt.ylabel('Score')
plt.grid(color='w', alpha=0.2)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8')

y = [50, 20, 15, 5, 10]
x = ['Chrome', 'Edge', 'Firefox', 'Opera', 'Safari']

plt.barh(x, y, color='c', alpha=0.8)

plt.show()

# %%
import matplotlib.pyplot as plt

data = [50, 20, 15, 5, 10]
lb = ['Chrome', 'Edge', 'Firefox', 'Opera', 'Safari']

plt.pie(data, labels=lb,
        startangle=45,
        colors=['lightgreen', 'lightgray', 'lightblue', 'lightcyan', 'lightyellow'])

plt.show()

# %%
import matplotlib.pyplot as plt

font_options = {'family' : 'sans-serif',
                'weight' : 'normal',
                'size' : 16}

plt.rc('font', **font_options)

data = [25, 20, 35, 10, 5]
lb = ['Gray', 'Yellow', 'Pink', 'Green', 'Blue']
explode = [0, 0.1, 0, 0.2, 0]

plt.pie(data, labels=lb,
        explode=explode, startangle=30,
        colors=['lightgray', '#ffffcc', 'pink', 'lightgreen', 'aqua'], shadow=True, autopct="%.1f%%")

plt.show()

# %% [markdown]
# ## Project

# %%
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/data/NCHS1.csv')

display(df.head(5), df.tail(5))
# Out:
#    Year                                     113 Cause Name  \
# 0  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name          State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries  United States  169936                     49.4
# 1  Unintentional injuries        Alabama    2703                     53.8
# 2  Unintentional injuries         Alaska     436                     63.7
# 3  Unintentional injuries        Arizona    4184                     56.2
# 4  Unintentional injuries       Arkansas    1625                     51.8
#        Year                                     113 Cause Name  \
# 10863  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/data/NCHS1.csv')

print(df['Cause Name'].unique(),
      df['State'].unique(),
      sep='\n\n')
# Out:
# ['Unintentional injuries' 'All causes' "Alzheimer's disease" 'Stroke'
#  'CLRD' 'Diabetes' 'Heart disease' 'Influenza and pneumonia' 'Suicide'
#  'Cancer' 'Kidney disease']
#
# ['United States' 'Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'District of Columbia' 'Florida'
#  'Georgia' 'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas'
#  'Kentucky' 'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan'
#  'Minnesota' 'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada'
#  'New Hampshire' 'New Jersey' 'New Mexico' 'New York' 'North Carolina'
#  'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island'
#  'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont'
#  'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']

# %%
df = pd.read_csv('/content/drive/MyDrive/data/NCHS1.csv')
print('Old file', df.shape)

df2 = df[df['Cause Name'] != 'All causes']
df3 = df2[df2['State'] != 'United States']

df3.to_csv('/content/drive/MyDrive/data/NCHS2.csv', index=None)
print('New file', df3.shape)
# Out:
# Old file (10868, 6)
# New file (9690, 6)

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/data/NCHS2.csv')

print(df['Cause Name'].unique(),
      df['State'].unique(),
      sep='\n\n')
# Out:
# ['Unintentional injuries' "Alzheimer's disease" 'Stroke' 'CLRD' 'Diabetes'
#  'Heart disease' 'Influenza and pneumonia' 'Suicide' 'Cancer'
#  'Kidney disease']
#
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']

# %%
df = pd.read_csv('/content/drive/MyDrive/data/NCHS2.csv')

sum = df['Deaths'].sum()
sum_fm = format(sum, ',')

print('Total deaths:', sum_fm)
# Out:
# Total deaths: 36,280,583

# %%
df = pd.read_csv('/content/drive/MyDrive/data/NCHS2.csv')

df_ca = df[(df.Year == 2017) & (df.State == 'California')]

df_ca
# Out:
#      Year                                     113 Cause Name  \
# 4    2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 55   2017                          Alzheimer's disease (G30)
# 106  2017                 Cerebrovascular diseases (I60-I69)
# 157  2017       Chronic lower respiratory diseases (J40-J47)
# 208  2017                        Diabetes mellitus (E10-E14)
# 259  2017        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 310  2017                  Influenza and pneumonia (J09-J18)
# 361  2017  Intentional self-harm (suicide) (*U03,X60-X84,...
# 412  2017                      Malignant neoplasms (C00-C97)
# 463  2017  Nephritis, nephrotic syndrome and nephrosis (N...
#
#                   Cause Name       State  Deaths  Age-adjusted Death Rate
# 4     Unintentional injuries  California   13840                     33.2
# 55       Alzheimer's disease  California   16238                     37.1
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/data/NCHS2.csv')

df_diabetes = df[df['Cause Name'] == 'Diabetes']
sum_diabetes = df_diabetes['Deaths'].sum()

print('Total deaths of diabetes :', format(sum_diabetes, ','))

suicide_2015_2017 = df[(df['Cause Name'] == 'Suicide') &
                       (df['Year'] >= 2015) & (df['Year'] <= 2017)]

sum_suicide = suicide_2015_2017['Deaths'].sum()

print('Total deaths of suicide between 2015-2017 :',
      format(sum_suicide, ','))
# Out:
# Total deaths of diabetes : 1,399,943
# Total deaths of suicide between 2015-2017 : 136,331

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/data/NCHS2.csv')

df = df[df.Year >= 2010].groupby('Year').sum()

df[['Deaths']].style.format('{:,}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4fd37" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fd37_level0_col0" class="col_heading level0 col0" >Deaths</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4fd37_level0_row0" class="row_heading level0 row0" >2010</th>
#       <td id="T_4fd37_row0_col0" class="data row0 col0" >1,852,349</td>
#     </tr>
#     <tr>
#       <th id="T_4fd37_level0_row1" class="row_heading level0 row1" >2011</th>
#       <td id="T_4fd37_row1_col0" class="data row1 col0" >1,869,321</td>
#     </tr>
#     <tr>
#       <th id="T_4fd37_level0_row2" class="row_heading level0 row2" >2012</th>
#       <td id="T_4fd37_row2_col0" class="data row2 col0" >1,876,588</td>
#     </tr>
#     <tr>
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/data/NCHS2.csv')

df = df.groupby('State').sum().sort_values(by='Deaths', ascending=False)

df[['Deaths']].head(10).style.format('{:,}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_53e51" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53e51_level0_col0" class="col_heading level0 col0" >Deaths</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >State</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53e51_level0_row0" class="row_heading level0 row0" >California</th>
#       <td id="T_53e51_row0_col0" class="data row0 col0" >3,594,261</td>
#     </tr>
#     <tr>
#       <th id="T_53e51_level0_row1" class="row_heading level0 row1" >Florida</th>
#       <td id="T_53e51_row1_col0" class="data row1 col0" >2,533,472</td>
#     </tr>
#     <tr>
#       <th id="T_53e51_level0_row2" class="row_heading level0 row2" >Texas</th>
#       <td id="T_53e51_row2_col0" class="data row2 col0" >2,367,695</td>
#     </tr>
#     <tr>
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/data/NCHS2.csv')

df = df.groupby(['Cause Name']).sum().sort_values(by='Deaths', ascending=False)

df[['Deaths']].style.format('{:,}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4a26e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a26e_level0_col0" class="col_heading level0 col0" >Deaths</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cause Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a26e_level0_row0" class="row_heading level0 row0" >Heart disease</th>
#       <td id="T_4a26e_row0_col0" class="data row0 col0" >12,222,640</td>
#     </tr>
#     <tr>
#       <th id="T_4a26e_level0_row1" class="row_heading level0 row1" >Cancer</th>
#       <td id="T_4a26e_row1_col0" class="data row1 col0" >10,843,644</td>
#     </tr>
#     <tr>
#       <th id="T_4a26e_level0_row2" class="row_heading level0 row2" >Stroke</th>
#       <td id="T_4a26e_row2_col0" class="data row2 col0" >2,726,523</td>
#     </tr>
#     <tr>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8')

df = pd.read_csv('/content/drive/MyDrive/data/NCHS2.csv')
df = df[df.Year >= 2010].groupby('Year').sum()

plt.plot(df.index, df['Deaths'], 'ro-')
plt.show()

#df[['Deaths']].plot(kind='line', style='ro-')

# %%
plt.style.use('seaborn-v0_8')

df = pd.read_csv('/content/drive/MyDrive/data/NCHS2.csv')
df = df[(df.Year >= 2008) & (df['Cause Name'] == 'Kidney disease')]
df = df.groupby('Year').sum()

plt.plot(df.index, df['Deaths'], 'mD-')
plt.show()

# %%
plt.style.use('seaborn-v0_8')

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.size'] = 14

df = pd.read_csv('/content/drive/MyDrive/data/NCHS2.csv')

df = df[df.State == 'California'].groupby('Cause Name').sum()

#display(df)

df[['Deaths']].plot.bar(color='y')
# Out:
# <Axes: xlabel='Cause Name'>

# %% [markdown]
# Machine Learning - LinearRegression

# %%
from sklearn.linear_model import LinearRegression

X = [[200], [300], [500], [800], [1000], [1500]]  #weight
y = [100, 200, 350, 500, 600, 750]                #price

model = LinearRegression()
model.fit(X, y)

predict_price = model.predict([[400], [600], [1200]])

display(predict_price)

p_400 = format(predict_price[0], '.0f')
p_600 = format(predict_price[1], '.0f')
p_1200 = format(predict_price[2], '.0f')

print('400 grams =>', p_400, 'Baht')
print('600 grams =>', p_600, 'Baht')
print('1200 grams =>', p_1200, 'Baht')
# Out:
# array([259.88779804, 358.90603086, 655.96072931])
# 400 grams => 260 Baht
# 600 grams => 359 Baht
# 1200 grams => 656 Baht
